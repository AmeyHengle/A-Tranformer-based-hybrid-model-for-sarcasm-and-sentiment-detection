# %%
import numpy as np
import pandas as pd
import re

# %%
data = pd.read_csv('../dataset/main/training_data.csv')
data.head()
# Out:
#                                                tweet  sarcasm sentiment  \
# 0  "د. #محمود_العلايلي:أرى أن الفريق #أحمد_شفيق ر...    False       NEU
# 1  "مع فيدرر يا آجا والكبار 😍 https://t.co/hrBeHb...    False       NEU
# 2  “الداعون لمبدأ الاختلاط بين الجنسين؛ كالداعين ...     True       NEG
# 3  "@ihe_94 @ya78m @amooo5 @badiajnikhar @Oukasaf...     True       NEG
# 4  "قل شرق حلب ولا تقل حلب الشرقية ....وقل غرب حل...    False       NEU
#
#   dialect
# 0     msa
# 1     msa
# 2     msa
# 3    gulf
# 4     msa

# %%
sentiment_values = pd.read_csv('../dataset/lexicon dictionary/arabic-sentiment-lexicons.csv')
sentiment_values.head()
# Out:
#    Unnamed: 0 Arabic Term  Positive Count  Negative Count Buckwalter index  \
# 0           0      خفيييف               5               1           xfyyyf
# 1           1         حظظ               0              10              HZZ
# 2           2     موقادره               1               7          mwqAdrh
# 3           3        زفرة               0               6             zfrp
# 4           4        شاهي              98             104             $Ahy
#
#    Sentiment Score
# 0            0.988
# 1           -2.509
# 2           -1.497
# 3           -2.057
# 4           -0.170

# %%
# trial = data['tweet'][0].split()
# for word in trial:
#     print(word in sentiment_values['Arabic Term'])
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
for tweet in data['tweet']:
    if type(tweet) == str:
        pos_count, neg_count = 0,0
        sentiment_score = 0.0
        for word in tweet.split():
            if type(word) == str:
                if word in sentiment_values['Arabic Term']:
                    print(word)
                    pos_count += sentiment_values.query(f'Arabic Term=={word}')['Positive Count']
                    neg_count += sentiment_values.query(f'Arabic Term=={word}')['Negative Count']
                    sentiment_score += sentiment_values.query(f'Arabic Term=={word}')['Sentiment Score']
        data['total_pos_count'] = pos_count
        data['total_neg_count'] = neg_count
        data['total_sentiment_score'] = sentiment_score

# %%
data.head(20)
# Out:
#     Unnamed: 0  ... total_sentiment_score
# 0            0  ...                   0.0
# 1            1  ...                   0.0
# 2            2  ...                   0.0
# 3            3  ...                   0.0
# 4            4  ...                   0.0
# 5            5  ...                   0.0
# 6            6  ...                   0.0
# 7            7  ...                   0.0
# 8            8  ...                   0.0
# 9            9  ...                   0.0
# 10          10  ...                   0.0
# 11          11  ...                   0.0
# 12          12  ...                   0.0
# 13          13  ...                   0.0
# 14          14  ...                   0.0
# 15          15  ...                   0.0
# 16          16  ...                   0.0
# 17          17  ...                   0.0
# 18          18  ...                   0.0
# 19          19  ...                   0.0
#
# [20 rows x 8 columns]
