# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('D:\github\Arabic-Sentiment-Identification\dataset\main\preprocessed_3.csv') #preprocessed_3 path here

# %%
data.head(50)
# Out:
#     Unnamed: 0                                              tweet  sarcasm  \
# 0            0  محمودالعلايلياري الفريق احمدشفيق رقم مهم المعا...    False
# 1            1                               فيدرر يا اجا والكبار    False
# 2            2  الداعون لمبدا الاختلاط الجنسين كالداعين لالغاء...     True
# 3            3  مساكين الصبح هوما رايحين راجعين عاي غوغل تعبت ...     True
# 4            4  قل شرق حلب تقل حلب الشرقيه وقل غرب حلب تقل حلب...    False
# 5            5    طبيب المقاصه اصابه احمدالشيخ بسيطه تحتاج للراحه    False
# 6            6  مرسي مش هنام اكتر اربع ساعات نمت دقيقه كمان زي...     True
# 7            7                                 انتخبواالبرص مشكله     True
# 8            8   هاشتاق العرب فيديو اهالي القدس يرفعون الاذان ...    False
# 9            9  ▪️محافظ العاصمه تفقد سير العمليه الانتخابيه لج...    False
# 10          10  الاتجاه اوباما يصل اسراءيل للمشاركه بدفن بيريس...    False
# 11          11                   والله عليش مايمدي ايفون يا حبيبي    False
# 12          12                                                هذا    False
# 13          13  مدريد كلوب اميركا نصف النهاءيالساعه ١٣٠ الظهر ...    False
# 14          14  وقت الشده ظنتي الجيش المصري حيوقف السعوديه مار...     True
# 15          15  عمليات الانبار تحرر جزيره هيت بالكامل مجرمي دا...    False
# 16          16  القطريين اختتطفو لانهم الاسره الحاكمه لانهم سن...    False
# 17          17  انت لسه مبقتش شركاء اوبر الفرصه لسه فاديك خطوا...    False
# 18          18  مفحوص مفعوص حماه المحتله حماه وحلب والساحل الن...     True
# 19          19  عاجل عرسال عاصفه ثلجيه تهدد حياه الالاف النازح...    False
# 20          20  لوكانبخاطري نفسي اطلع لعمل تطوعي لمساعده الناز...    False
# 21          21  انا اشفق هيلاري كلنتون فهي مضطره لمناظره خبل ن...     True
# 22          22  دولهالخلافه القوات العراقيه تفكك العبوات الناس...    False
# 23          23  ﺣﻤﺪﻳﻦﻋﺎﻭﺯﻳﺤﺎﻛﻢﺍﺳﺪﺍﻟﻌﺮﺏ برضو سانتخبالسيسيومشهنز...    False
# 24          24  انتخاب مرسي بالقطع سبه ولدي اصدقاء اشك ثوريتهم...    False
# 25          25  خطرفيالقدس يزداد الخطر بزياده الغفله واللامبال...    False
# 26          26  العصابه الوهابيه تحارب جبهه النصره وتركت جيوش ...     True
# 27          27  هههههههههههههه كمان حكاها بشار الاسد صلي العيد...     True
# 28          28  ماجدهواصف اعرف سماالمصري مهرجانالقاهرهالسينماء...     True
# 29          29  ⁧الارهابصناعهامريكيهلاسعوديه⁩ ⁧قانونجاستا⁩محمد...    False
# 30          30                  كنت اتابع فيدرر بس كرهت نادال طلع    False
# 31          31                  شمعه الكترونيه لمستخدمي اجهزه ابل    False
# 32          32  حزبالله فيلقالقدسيتحدث فلسطين يقتل العرب ويدمر...    False
# 33          33  الاعلامي عكاشه اتغيردرجه بقي بيبرر ارتفاع الاس...     True
# 34          34                                          جستن بيبر    False
# 35          35                            حماس مشعل بعيون اسراءيل    False
# 36          36  حواري النجمه الذهبيه نوالالزغبي صفحات جريده ال...    False
# 37          37  الانفاق قاتله الجنود والمدرعات حلب جبههالنصره ...    False
# 38          38     انا انصحك تعدل لغتك العربيه بعدها تدخل الجامعه    False
# 39          39  طول انا بتخانق وبعاتبك يبقا لسه باقيه وبحبك ال...    False
# 40          40                                    نادين نسيب نجيم    False
# 41          41      اجاني نوتفكيشن حسيت حالي بحساب جستن بيبر يعمي    False
# 42          42  اللهم نصرت عبدك موسي فانصر عبادك العراق سوريا ...    False
# 43          43                                            محد صاح    False
# 44          44  يعني اساس حلف الناتو والسعوديه وتركيا وقطر كنت...    False
# 45          45  الاهليضمكدوووريالمحترررفيناذا اراد احدكم الكلا...    False
# 46          46  كارثه يرتكبها يقول المولدالنبوي بدعهالاسلام اه...    False
# 47          47  الله يرحمه ويعفو عنهكان حزب الخونهاللهم تجاوز ...    False
# 48          48  اللهم انصر اخواننا حلب وارحم المستضعفين منهم و...    False
# 49          49                               قلبي رجل❤️ يلغي رجال    False
#
#    sentiment dialect
# 0        NEU     msa
# 1        NEU     msa
# 2        NEG     msa
# 3        NEG    gulf
# 4        NEU     msa
# 5        NEG     msa
# 6        NEG   egypt
# 7        NEG   egypt
# 8        POS     msa
# 9        NEU     msa
# 10       NEU     msa
# 11       POS    gulf
# 12       NEG  levant
# 13       POS     msa
# 14       NEG   egypt
# 15       NEU     msa
# 16       NEG     msa
# 17       NEU   egypt
# 18       NEG     msa
# 19       NEU     msa
# 20       POS  levant
# 21       NEG     msa
# 22       NEU     msa
# 23       NEG   egypt
# 24       NEU     msa
# 25       NEG     msa
# 26       NEG     msa
# 27       NEG  levant
# 28       NEG     msa
# 29       NEG     msa
# 30       NEG    gulf
# 31       NEU     msa
# 32       NEG  levant
# 33       NEG     msa
# 34       NEU     msa
# 35       NEU     msa
# 36       POS     msa
# 37       NEG     msa
# 38       NEG   egypt
# 39       NEG     msa
# 40       NEU     msa
# 41       NEU  levant
# 42       POS     msa
# 43       NEU     msa
# 44       NEG    gulf
# 45       NEU  levant
# 46       NEG     msa
# 47       NEG     msa
# 48       POS     msa
# 49       POS     msa

# %%
data['tweet'][11969] = 'nan'

# %%
data_tweets = data['tweet'].copy()
print(type(data_tweets))
# Out:
# <class 'pandas.core.series.Series'>

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(oov_token = "[OOV]")
tokenizer.fit_on_texts(data['tweet'].values.tolist())

# %%
def get_word_embeddings(filepath, vocab, embedding_dimension):

  word_embeddings = np.zeros((len(vocab) + 1, embedding_dimension))
  embedding_file = open(filepath, "r", encoding = "utf8")
  count = 0

  for line in embedding_file:
    line = line.split()
    word = line[0]
    print(f'outside {word}')
    if word in vocab:
      print(word)
      word_vector = np.asarray(line[1:], dtype = "float32")
      if len(word_vector) == embedding_dimension:
        word_embeddings[vocab[word]] = word_vector
      else:
        print('\nVector size does not match with embedding_dimension:\t', word_vector)
      count+=1

  print("Total word embeddings read: {}\n".format(count))
  embedding_file.close()
  return word_embeddings

# %%
word_embeddings = get_word_embeddings('D:\Mazajak100m.vec', tokenizer.word_index, 300)
# Out:
# C
# outside الحنفيه
# الحنفيه
# outside ينازع
# outside الذكره
# outside بالذنوب_متسلي_هو
# outside شخصا_بينهم
# outside نهاية_جهدي_فرح
# outside ونغيب
# outside بغيتها
# outside آلجنون
# outside علي_متعمدا_فليتبوأ
# outside اغفرلنا_ذنوبنا
# outside للاهلاويه
# outside اسلوبي_حلو
# outside ميضحك
# outside نائب_رئيس_الجمهورية
# outside مفتقده
# outside دعائنا_فأنت_أعلم_بحاجاتنا
# outside الاشياء_حتى_اثمنها
# outside بصلح
# outside إحباط_محاولة
# outside مخابز
# outside وصية_قرآنية_واصبر
# outside وحراس
# وحراس
# outside أعناقهم
# outside والناس_بالمثل_ترزقها
# outside أنتظرونا
# outside ننظم
# outside سيساوى
# outside @aa_nn92
# outside وروي
# outside طيبا_هكذا
# outside يمكن_تطوف_واحد
# outside اللهم_اني_احتسبت
# outside شئتم_أم_أبيتم
# outside يا_رب_أثلج
# outside تباهى_بهجرك_اتركه_للهوى
# outside أجمل_المواساة_وأوصلها
# outside السلطات_#السعودية
# outside وحبيني
# outside ومجمل
# outside حد_نسيان_المحاسن
# outside غرزة
# outside بدمائكم
# outside تعال_انطيني_عطرك
# outside خوف_والطمأنينة_التي
# outside صادزه
# outside @magd1987m
# outside وأغلبها
# outside سألها_القاضي_لماذا_قتلتيه
# outside ليس_مبرر_فقالت
# outside ربنا_عارف_احساسنا
# outside وما_القيراطان_قال
# outside هالمجلس
# outside إتساع_المدى_وكثرة
# outside شعيرة_الأمر_بالمعروف_والنهي
# outside هي_مبتغانا
# outside التي_تترك_أثرا
# outside رددو_معي_استغفرالله
# outside لذيذ_الحكي_منك
# outside مدري_وش_تسوي
# outside متلخبطه
# outside أستغفر_آلله_آلعلي
# outside إن_زارك_الحزن
# outside وتجيبه
# outside نشفى
# outside بارده_مبرده
# outside يستضعف_اللي
# outside #الملك_سلمان_حفظه
# outside آلجمال
# outside #احبكم
# outside غرس_الجنة
# outside شروطك
# outside تحريات
# تحريات
# outside إمام_جامع
# outside الحنين_ولاني
# outside تروحله
# outside لفوزه
# outside بعض_الأزواج
# outside @OAbdelmagid
# outside الدمعة_التي
# outside ومترجم
# outside تعقيم
# outside تعلنون
# outside نفسي_واخشى_يمسك
# outside جيش_وطني
# outside عالبلد
# outside إني_وليتك_أمري_فأعوذ
# outside بدون_علمك_بنفسك
# outside مو_كاسر_خاطري
# outside بائسين
# outside مهبه
# outside نعليا
# outside كنموذج
# outside مراد_بوز
# outside الأسبوع_الثاني
# outside دماغو
# outside احاسيسنا
# outside عملك_فاختر_أعمالا_يسرك
# outside فمازلت
# outside السيئة_عني
# outside بالتصريحات
# بالتصريحات
# outside 6400
# outside هو_أسفل_منكم
# outside ذلهم
# outside واجعل_جنة_الفردوس
# outside تتلمذ
# outside متحدث_باسم
# outside ملكيتها
# outside اننننننن
# outside شيء_يشعرك_بالفرح
# outside أسمائه
# outside لقيت_الوصل_بوصاله
# outside وأهديك
# outside مصخر
# outside ودهاء
# ودهاء
# outside الماشي_إلى
# outside المروحية
# outside إنشراح_الصدر
# outside أعطيني_تم
# outside الشويب
# outside السبيكه
# السبيكه
# outside الزعيم_الصالح
# outside العبادل
# outside قلبك_وعينك
# outside يعقوب_بيوسف_وبشرنا_بالفرح
# outside الجيوب_الفقر_فقر_العقول
# outside خيرا_ورزقا_نكتسبه
# outside سيزر
# outside شخص_تحبه_ويسمعك_صوته
# outside هي_قاسيه_لكنها
# outside كانوا_يعملون_يسيرا_ويؤجرون
# outside اختتام_فعاليات
# outside صلاه_العصر
# outside طينة_البشر
# outside رتويت_وراح_اتابعك
# outside @alwaaaleeed
# outside وإن_بعدت_فعد_وإذا
# outside إسهاب_إياك_أن
# outside #الأهلي_نجران
# outside نفسيتي_محتاجه_احد
# outside الروائية
# outside اجزت
# outside @azizd_11
# outside فإن_الهوى_يقود
# outside وسياسيا
# وسياسيا
# outside والا_تغليت_اليوم
# outside زعلنا_لين_قلنا
# outside ضيقه_تؤلمني_ومن
# outside بي_الاسباب
# outside مهما_جارت_عليك
# outside ماعمري_درست_عشان
# outside @3almi_makkah
# outside يمرك_ألف
# outside 17_مارس
# outside 89_عام
# outside عبدالمجيد_الذيابي
# outside قد_تسلب_الكثير
# outside @13chaimaa520365
# outside #SouhilaBenLachhab_#الجيش_السوهابي
# outside وحدهم_الموتى
# outside ما_أحس_بالوقت
# outside بلغنا_شهرك_الكريم
# outside يحيى_خرمي
# outside مرارة_إيامي
# outside حظوظ_الدنيا_اطيبها
# outside اسقينا_الفرح
# outside @asoora__a
# outside للكلام_ولو
# outside التي_بين_أضلعنا
# outside قد_الخطا_البين
# outside #إخوتي_في_الله
# outside #رفع_اسعار_البنزين
# outside @fay_badr
# outside الذي_يفتقده_غيرنا_ميزانيتنا
# outside شوف_وتمتع
# outside #لن_يتزوجكي_لانك
# outside 151231
# outside #شي_ودكم_ينقرض_ب2016
# outside فوق_راسنا_وانت
# outside #خلوة_المائة
# outside @a2_from
# outside قد_يكون_فاشلا
# outside #قروب_حلم_غامد_للدعم
# outside الحياة_إنها_تنصف
# outside ذا_كوين
# outside #بس_بلبنان
# outside #غيابك_أثر_فيني
# outside هالفتره_يراضي_نفسه_بنفسه
# outside @rfrf1432
# outside @Ullll6
# outside #اقترح_طريقه_لقتل_الشواذ
# outside #عودو_ليعود_نصركم
# outside #الدوشجيه_فولورز_الصبحيه
# outside #لف_وارجع_اخلاق_بيسو_بتوجع
# outside بالأقدار_الدنيا
# outside تفجير_أنقرة
# outside #الهلال_في_مجلس_قناة_الكاس
# outside @Kq2406
# outside @_razri
# outside #روان_العلي
# outside #هتمني_من_ربي
# outside #وعلشان_انا_مسلم
# outside #بتاع_البترول_صباحو_فولورز
# outside #تدمر_مقبرة_الغزاة
# outside #كارتون_احبه_للحين
# outside #تفكر_في_الهدايه
# outside لنا_بلطفك
# outside #حياتي_اتغيرت_لما
# outside @anrmyn09
# outside #عصف_الغيارى
# outside تعالى_لعلاج_العقم
# outside وضعف_الإخصاب_والإنجاب_للرجل
# outside #شباب_مظلوم
# outside #انت_من_جيل_مسلسل
# outside #عادات_رمضانيه
# outside إن_عشر_الرحمه
# outside #القوات_المسلحه_العراقيه
# outside معزبه
# outside لامأوى_لهم
# outside ترافقنا
# outside ياخذ_ويعطي
# outside فاقد_الامل
# outside بالحالة
# outside بعه
# outside المداد
# outside افراد_المجتمع
# outside بيني_وبينك_عامر
# outside #StaracArabia_#HananeElKhader_#IhabAmir
# outside الغرابي
# outside والاستقلال
# والاستقلال
# outside لتقويم
# outside حبيييبي
# outside فيها_والحقد_فرق
# outside hello
# outside تاخدك
# outside اقتربت_الساعة_وانشق_القمر
# outside بهذا_الاسلوب
# outside #القوات_السعودية
# outside مرشح_الجميع
# outside عن_عائشة_زوج
# outside زمنا_طويلا
# outside لما_ابوك_يقولك
# outside أجمل_الأرزاق_سكينة_الروح
# outside ناس_ابتعدت_بكامل
# outside الاحد_الجاي
# outside تساوي_شيئا_كذلك
# outside بيسهر
# outside يوم_وليله_فلا
# outside غدا_وهو_صائم
# outside لحظيا
# outside مازال_هناك_ضحكات
# outside @bravvex999
# outside تجمدنا
# outside يا_مسهل_الشديد_ويا
# outside توانسة
# outside تملؤه
# outside الفتاكة
# outside كلمات_راقت_لي
# outside إعتذر_لربك_عن
# outside بوافق
# outside كطفله
# outside للشكر
# للشكر
# outside مومياء
# outside ع_فكرا
# outside الغبره
# outside ايامنا_القادمه
# outside المغاربي
# outside ظننت_أنك_أني
# outside واخوته
# outside هالغيره
# outside @farah20112013
# outside لأصحابك
# outside يومة
# outside زودي
# outside @wweewew30
# outside الأناقة_نظافة_قلبك
# outside ولا_يهمج
# outside زح
# outside @wadeemaaaa
# outside #تلفزيون_قطر
# outside المستخدمه
# outside الفقر_الذي_يعيشه
# outside دار_جزاء
# outside إعلاميي
# outside مدعوما
# outside الغطاء_لعبده_وأظهر
# outside غطو
# outside للأغبياء
# outside ويتغنى
# outside لعلي_أبقى_جميل
# outside هؤلاء_الاطفال
# outside انيسه
# outside جو_جو
# outside 287
# outside هقيت_انه
# outside @FahadTomahook
# outside @qawsedrhaya
# outside عمره_ندم
# outside للأكاديمية
# outside محورها
# outside الأيام_وموسم_البركة_فاحصد
# outside أكلتها
# outside برادلي
# outside بالحلق
# outside ويكفر_عنهم_سيئاتهم_ۚ
# outside شارع_رئيسي
# outside وصلت_الفكرة
# outside هواك_يعذب
# outside اسهل_6
# outside @nuoof23
# outside إلعن
# outside قال
# outside ماعاد_تجرحني_غيابات_الأحباب
# outside متى_وأغلب_أوجاعي
# outside الهاندفري
# outside الجاهله
# outside تعاقبه
# outside مامل
# outside يد_ملكة
# outside #رسائل
# outside وجنبك
# outside نظرها_ملايين_والقلب_يعشق
# outside قطعت_الوصل
# outside ورزقا_لكل
# outside #تقارير
# outside للكرامه
# outside دائما_فتنسى_نفسك
# outside بكى_والكل_يدري
# outside طعامه_قال
# outside ذوق_وب
# outside كانو_بيننا_احياء
# outside للكسل
# outside عش_بالأمل_عش
# outside لسعود_غربي
# outside هشتري
# outside ولااااا
# outside @Q__sahar
# outside المنيح
# outside والاهالي
# والاهالي
# outside لن_تخرق_الأرض
# outside يضربهم
# يضربهم
# outside مافوق
# outside كل_يوم_تغطيك
# outside مجرد_استشعارك_أنها_حبيبتان
# outside نشفق
# outside أزورك
# outside والهيئات
# outside الداوم
# الداوم
# outside باخرة
# outside مفضلتي_2⃣_رتويت
# outside وتتأثر
# outside أجعل_قبره_روضه
# outside العميد_احمد_عسيري
# outside تسسستاهل
# outside لك_حسنات_تجري
# outside أغلق_عيني
# outside الدنيا_ذكرني_بأنها
# outside @rabiih
# outside الحياه_الزوجيه
# outside لون_شعرها
# outside مثل_عينها_عتابها
# outside مشتاقتلها
# outside @i_you233
# outside فلا_تحتقر
# outside اوان
# outside لألعاب_القوى
# outside آدمين
# outside دج
# outside العادلي
# العادلي
# outside تكون_مجبور_تضعف
# outside نيك_جماعي
# outside تجربتنا
# outside فيصدمك_بصغر_عقله
# outside المؤمنون_#Quran
# outside عوفي
# outside التلقي
# outside بتوضح
# outside العالم_مثل_مايريدون
# outside أكون_وأفعل_م
# outside قل_للذين_كفروا_ستغلبون
# outside يطبقونه
# outside @ahmad_Almatrodi
# outside عدا_الإحساس
# outside للشاي
# outside عينيك_جهاد
# outside آذان_المغرب
# outside لجنودنا_المرابطين
# outside كانون_الثاني
# outside مر_طاريه_أحس
# outside معشوقنا
# outside لاتجيد
# outside يانااس
# outside الناطقة
# outside لأنفسكم_حياة_تلهيكم
# outside افلام_الكرتون
# outside قال_تعالى_وبشر_الصابرين
# outside @Tyamo17
# outside كيف_اوصفك
# outside @nooonoo2424
# outside فكلي
# outside وتتواصل
# وتتواصل
# outside أحببت_شخصا
# outside القايمه
# outside باءت_بالفشل
# outside وسيعوضك
# outside التنورة
# outside ونصمت
# outside تستقم
# outside اللحظات_السعيدة
# outside @Abdokishk4
# outside بالطريقه_دي
# outside لاحتوائها
# outside جرافيتي
# جرافيتي
# outside وطينا
# outside منطلقا
# outside اسم_الاغنيه
# outside لحدن_يساومنا
# outside جنوب_غربي
# outside بتخبي
# outside لجماهير_الاتحاد
# outside زآن
# outside ألبسها
# outside صدوف_الليالي
# outside ألف_مبروك_ياآنيقه
# outside مسكونة
# outside والجامية
# outside النادي_العلمي
# outside 294
# outside ثلث_القرأن
# outside ينتظرونه
# outside جبريه
# outside يغط
# outside الحظيظ
# outside فور_يو
# outside @1997_njoud
# outside تستمتع_باليوم
# outside افرحت
# outside أسباب_وجع_الراس
# outside يكون_كتفك_وساعدك
# outside الاسكرين_شوت
# outside والهمس
# outside #سالم
# outside نذهب_الى
# outside خاتم_الأنبياء_والمرسلين
# outside تدبير_أمورنآ
# outside انت_وربعك
# outside غسول
# غسول
# outside كااامل
# outside الهذلول
# outside @Nor__201
# outside حكايات_الغرام_وإن
# outside シ
# outside أهديتها
# outside والحاج
# outside والتخفيف
# والتخفيف
# outside الخير_وارضني_به
# outside نحن_قادمون
# outside مخيب
# مخيب
# outside مواليد_شهر_12
# outside مكنتوش
# outside اجممممل
# outside امنيت
# outside تستوحشوا_طريق_الحق_لقلة
# outside مايشيل
# outside سحب_الجناسي
# outside بأهلها_وعدد_ما
# outside يرحم_اموات_المسلمين
# outside وقلة_الحياء
# outside لأمراض
# outside أبوك_وأمك
# outside ضع_العدسة_المكبرة_جانبا
# outside يخذلك_مرة_سيخذلك
# outside @Kaspersswag
# outside صوتك_جاب_ضحكاتي
# outside داخلنا_تماما_مضطرين_نخبي
# outside دوليين
# دوليين
# outside بماده
# outside المغازي
# outside بيمثلوا
# outside هانية
# outside وفلو
# outside وساند
# outside موطن_يحب
# outside تلقائى
# outside @S0rage
# outside ذرياتنا
# outside وقني_شرما_قضيت_إنه
# outside قاعدا
# outside طموحاتنا_واكبر_مطامعنا_ان
# outside ما_ينبغي_لعبد
# outside صالح_العنزي
# outside شكلي_بسوي
# outside جنيني
# outside كفي_وشميته
# outside #عن_بعد
# outside بالمذنب
# outside الفشخرة
# outside @mooon_778
# outside ليغفر_لك
# outside إنه_سميع_مجيب
# outside أصعب_إجابه_قلتها
# outside وصلني_خبر
# outside اشمك
# outside #العراقية
# outside أعطا_وتشفي_مريض_مالقى
# outside 7_عناصر
# outside تطاردني
# outside له_غصب_كنك
# outside كشخصية
# outside لزملائي
# outside بالانقلاب
# بالانقلاب
# outside قااال
# outside تفتق
# outside يهداج
# outside سبحاااان
# outside أنسيت
# outside ماعرفو
# ماعرفو
# outside كثفوا
# outside رغم_أنفه_قيل
# outside اسوء_علاقه_هي
# outside اوجاع_الحياه
# outside الدنيا_ونار_جهنم
# outside لفقراء
# outside وتضرر
# outside رأي_فكن
# outside الحنين_مبكيه_رحم
# outside وتطفي
# outside الغلا_حيه
# outside فقربك
# outside أجزم_بأن
# outside هذه_الفتوى
# outside اشرقت_شمس
# outside وعين_الرضا
# outside الحلم_يستحقون_حفاوة_أكثر
# outside أحد_وتجاهل_المحبطين
# outside تائب_نقي_اينما_مت
# outside لكما_وبارك_عليكما_وجمع
# outside ابيض_الوجه
# outside وسطاء
# outside بهاك
# outside يستعبد
# outside أبوبكر_الصديق
# outside للثالث
# outside انضموا_إلينا
# outside RT_Eyaaaad
# outside خلصة
# outside ظلمت_نفسي_كثيرا
# outside ولاننا
# outside أني_عرفت_قيمتي
# outside القتال_ضد
# outside صرتم
# outside البقرة_119
# outside تنفيذ_برنامج
# outside الحمد_خاتمة_النعمه
# outside #حمدونيات
# outside شرما
# outside تضميني
# outside وفزعة
# outside ماعلينا_منهم
# outside سنين_طوال
# outside ليس_بكثرة_الموجودين
# outside والبطن
# outside مونتاجات
# outside المسئ
# outside أعملوا
# outside مضغة
# outside بيساعدك
# outside أن_القوة_مرادف
# outside خطآك
# outside @shog_alsh1
# outside #الغروب
# outside بالهاشتاغ
# outside @alalwany195
# outside اللي_ضميره_بالبشر
# outside اتهامهم
# outside نجوم_العالمي
# outside الحدب
# outside عمل_شاق
# outside ملبين
# outside مبكره
# outside ورتاح
# outside #سداح
# outside الشك_باب_ويفتحه
# outside للعلمانية
# outside اعطهم
# outside مش_هيسيبك
# outside سنتوب
# outside بساعد
# outside كساها
# outside له_شاعر_يترجم
# outside مستوى_سيء
# outside @Kuwait_first_1
# outside خفيف_لطيف
# outside حبي_لك_ونبرتك
# outside نخيتكم
# outside البيب
# outside تنام_عيت_تموت
# outside واشرح_صدرها
# outside بريقي_وما_شكري
# outside الفجر_ممن_عفوت
# outside ازعاجه
# outside حرام_انك_تراعيها
# outside ارعى_خياله
# outside تهنأ
# outside قنوات_بي
# outside #الفتن
# outside مدارسكم
# outside مخرج_9
# outside #الكريسماس
# outside عثمانية
# outside ياليل_عطني_مابقى
# outside ربطوا
# outside فتاويهم
# outside احج
# outside ونايمه
# outside تشاركونا
# outside نعما
# outside ينظر_إليك_متمنيا
# outside السماوات_والأرض_يمرون
# outside ونكبر
# outside ونماذج
# outside وشيفو
# outside ولما_طلبت
# outside ويهددون
# outside تعلمت_لأجلك_لغة
# outside قريتهم
# outside الاستغناء_بسهولة
# outside يبارك_فيكى
# outside ي_جمهور_الذهب
# outside معلوماتهم
# معلوماتهم
# outside يحلم_بأن
# outside لهم_ابشروا_بروح
# outside بيتحط
# outside ماتنبلع
# outside وخبيث
# outside تلبسني
# outside بان_عيبه
# outside أعدك_بأن
# outside المحكمة_الدولية
# outside نووف
# outside ذويه_الصبر_والسلوان
# outside يارب_وفق_نصرنا
# outside هالدنيا_بدونك
# outside تريد_ستجد
# outside وكواك
# outside ب_إهمالك
# outside لسعر
# لسعر
# outside ولستم
# outside الاستهانة
# outside لعلها_خيرة
# outside ي_ويل_حآلي
# outside الأيام_تجمعنا
# outside لست_أذكره_وكيف_اذكره
# outside مترو_الرياض
# outside لوفيه
# outside وتتخيل
# وتتخيل
# outside وإطلاق_النار
# outside بكلفة
# outside ماتسلم
# outside بيننا_صد_وجفا
# outside مصدعة
# outside الطقاقات
# outside @7MO0O0D3E
# outside ️عطني_تم
# outside اشحنه
# outside احقاقا_للحق
# outside ومكيف
# outside اذكرج
# outside طالت_مسافاتك_تدل_خطاك
# outside هناك_بالكتاب
# outside فوربس
# outside الميك_أب
# outside فهو_ليس_ضعفا
# outside سرابي
# outside والله_محل_اللوم
# outside بدايه_ليوم
# outside مفضلتي_بالترتيب
# outside وشغلت
# وشغلت
# outside بصاروخ_#تاو
# outside ريحتني
# outside اجعلني_ممن_يصلي_الصلاه
# outside الدنيا_سلف_ودين
# outside ورصيد
# outside إطلاع
# outside مانشوفها
# outside يمانية
# outside غير_معابين_ولا
# outside @Z_a_zo
# outside سوء_أدب
# outside يوسف_علاونة
# outside وحبر
# outside ماهي_خسارة_تكسب
# outside يحرمنا_منكم
# outside ياملاذي
# outside يعاقبهم
# outside للعظيم
# outside مبرووووكك
# outside واقنع
# واقنع
# outside #NKO
# outside الإطاحة_ب
# outside اللي_نقوله_نفعنا
# outside صلاة_ركعتين
# outside برامج_التواصل_الإجتماعي
# outside كولو_توريه
# outside شر_الأشرار
# outside منهم_براء
# outside بشاميل
# outside وتفاني
# outside الرحل
# outside تشآء_واتركهم_يفهمونك_كيفما
# outside آتيه
# outside بنحلم
# outside ذيي
# outside تخليت_عني
# outside فهمناها
# outside عدو_شريف_بقدر
# outside سما_هالكون_كلن_يحتريه
# outside مطبوخ
# outside تجلسي
# outside آلآلم
# outside أعلم_بأني
# outside يهتم_لامري
# outside إقليميا
# outside أبن_القيم
# outside ناشرين
# outside ونستانس
# outside تسدح
# outside الليل_للصبح
# outside راعيه_مصير_الزمان_يقفي
# outside الونات
# outside ويش_سويت
# outside مستوى_عال
# outside اللي_تسره_همومك
# outside العمر_وأنا_ساجد
# outside ولو_نمت_جايع
# outside وزرع_الأثر_فإن
# outside تاريخ_الدوري_السعودي
# outside ما_قل_مردودي
# outside نبينا_وقدوتنا_محمد
# outside امسح_دموعك_بحسن_الظن
# outside مقطعا
# outside والتحفظ
# outside كلما_احسنت_نيتك
# outside @0llGl
# outside اقامته
# اقامته
# outside ليشعرك_بغياب_كل
# outside وحل_الوقاحه
# outside اعداءهم
# اعداءهم
# outside المرقوق
# outside بدى_فحل_جاد_يفوت
# outside @fahad_alenazii
# outside متكلمتش
# outside استباحة
# outside مبآرك_لك
# outside ترى_الوقت_دوار
# outside والقيادي
# outside مسساء_الخيير
# outside مايقدره
# outside يقال_لهم_إدخلوا
# outside أحبه_ضاع
# outside بيركز
# outside حينما_ينادي_الرحمن
# outside توديع_بعض
# outside الكسار
# outside سونا
# outside وشوشهم
# outside ياغزال
# outside اغفر_لها_ذنوبها
# outside ويوفقها
# outside للمناصب
# outside لازم_يفهمون
# outside نبتة_الصبار_أن
# outside @Nylwfr4
# outside ولا_فسوق
# outside 17_12_2015
# outside وإيطاليا
# outside مش_ناوى
# outside العآشق
# outside اعتراف_صريح
# outside اعاتب_الوقت
# outside واطرح
# outside وشعوبها
# outside لي_زين_وافهم
# outside خاطري_جاه
# outside اسألك_وكلي_شفقة
# outside 319
# outside فولوباك_التزام_وصدق
# outside بكاف_عبده_هناك_تلازم
# outside المتعاملين
# outside صاير_غريب
# outside حروف_تكتبهآ_تلك
# outside سأهديك
# outside @lebanonidol
# outside كان_شوفه_شوف
# outside وأبى
# outside يقتلون_المسلمين
# outside بينهي
# outside فاتكم_فأتموا_صحيح_البخاري
# outside وضوابط
# outside ياطالب
# outside أنا_دنيتك_الثانيه
# outside ولايكات
# outside كان_عنه_مسؤلا
# outside @horyaksa
# outside صفوه
# صفوه
# outside @mona_syriaaa
# outside صلاحياتهم
# outside @omsarah971
# outside يريدون_رؤية_أوهامهم_تتحطم
# outside الجنة_دارنا
# outside قلبي_وتفكيري
# outside ثلاثة_أسابيع
# outside وانا_غاسله_يدي
# outside الاهوال
# outside @khalsaalamri
# outside يمسى_كان_حقاعلى
# outside الأزهري
# outside الورد_يسعد_صبآحكم
# outside بالمنافسه
# outside حاسس_بيها
# outside سواك_وان_لامس
# outside تفجير_مسجد
# outside هالدكتور
# outside الذي_ينسيك_أفراح
# outside بألحان
# outside واجعل_الحوض_موردا_لها
# outside شاااااركو
# outside تخليك_تركن_جميع_أمانيك
# outside آبيك_حب
# outside باعتها
# outside يزرع_الطيب_ماخابت
# outside وأهش_بها
# outside يا_شارح_الصدور_وميسر
# outside رايتي
# outside ذوقك_الرفيع
# outside بالثلوج
# outside بسبب_الاصابه
# outside وظفوا
# outside وتجاوز_الصعاب_اهدنا_للسير
# outside حجبها
# outside أنت_قريب_فألقاك
# outside اسرع_باااك
# outside بمحادثة
# outside #هدير
# outside #فتاة
# outside الذي_لايعلمه_غيرك
# outside لعبادك_مغاليق_الأسباب_والأبواب
# outside واكشف_كروبهم_ونور_دروبهم
# outside الجرابيع
# outside افندم
# outside اهل_القلوب_الوفيه
# outside وقت_إستجابه
# outside حنا_بشر_نخطي
# outside مهمآ_حصل
# outside مؤسسات_الدوله
# outside رسلان
# outside وأرسى_الجبال_لاتعجزه_ضخامة
# outside الأبنية
# outside النفس_تميل
# outside محدن_بكامل_والبشر
# outside ودي_تعلمني
# outside @TefO_Ahmed
# outside عندي_بالزمن
# outside لزومي
# outside ثانيه_للعد
# outside مصالحك
# outside مثلهآ
# outside الإعتصام
# outside #صحيفة_حضن
# outside نمت_ولم_استيقظ
# outside وصالك_إحفظ_وصاله_وإشتر
# outside تفضلين
# outside ملامحنا_الشوق
# outside بما_أشاء_أعطيتك
# outside انت_اعلم_بحالهم
# outside حبرك
# outside @fo0o_of
# outside س_نعوض_بكل
# outside قيمة_السهم_100
# outside تستسلم_للظروف
# outside ما_ستلتقي_بشخص
# outside تنفيره
# outside @talalalyagout
# outside يحرمني_كرمك_او
# outside الثانية_لأجل
# outside بصفتك
# outside جنون_البقر
# outside logo
# outside بلدان_المسلمين
# outside #ولاية_ديالى
# outside خفوقه_مراده_والله
# outside نجاح_بلا_كد
# outside مليشيا_الحشد
# outside @ghranchannel
# outside محترقة
# outside بالعاطفه
# outside علمانيه
# علمانيه
# outside بالينو
# outside جنود_الدولة_الاسلامية
# outside وسيلة_اتصالك_مع
# outside مرتااااح_واللي
# outside والباقيين
# outside @Warchieff
# outside ماله_مسمى
# outside @Glbyme3ak
# outside كذب_وتدليس
# outside قد_جف_حبر
# outside تزوجها_وفي
# outside فيكم_توضأ_الوتر
# outside الدنماركي
# outside جيتني_محتاج
# outside عن_الفرص_لمساعدة
# outside وولي_عهده_وولي_ولي
# outside شيء_قابل_للنسيان
# outside تعلم_مهارة_النسيان_ونظف
# outside الذي_ظننت_لوقت
# outside الشيخ_فواز
# outside الفلوس_غيرتك
# outside ربي_تركتهم_ليوم
# outside ولسان_حاله_يقول
# outside الرحماني
# outside الحلآ
# outside الباتريوت
# الباتريوت
# outside عمرك_ستعرف_إن
# outside كلمات_مؤثرة
# outside لنآ_ملآذ_ولآ_ملجأ
# outside الجيش_الجبوري
# outside الاهواز
# outside ماضحكتي
# outside وإن_طالت_المده
# outside @EssaAljokm
# outside @ayyad1975
# outside تمنيتك_نصيبي_يانصيب_الغير
# outside فلاتة
# outside مواليد_شهر_1
# outside @mshary1a
# outside خشوعا_الإسراء_109
# outside #عمري_قطر
# outside ما_أروع_الصدف
# outside امناء_الشرطه
# outside القضاء_العسكري
# outside تصدقني_اذا
# outside النعم_المستلذه_دائما_وابدا
# outside يشبه_تفاصيلها_الصغيرة
# outside @kokya_23
# outside #kehribar
# outside أيامه_ولياليه_وأنت_راض
# outside وسيقال_لك
# outside وان_شانت_الايام
# outside @500_bdooor
# outside يسمعك_فتسأله_ما
# outside العافيه_للنوم
# outside الارض_والتحفوا_السماء
# outside أحمد_آدم
# outside هي_ماتليق
# outside #شاعر_يستحق_الانصاف
# outside الظلم_وقهر_الرجال
# outside أنا_أفتقدت_أحباب
# outside #قروب_مطير_للدعم
# outside #مجعد_بن_متعب
# outside ياالله_ترزقنا_مثل
# outside #بعض_البشر_مثل
# outside ومال_غصن_الأمنيات_وتزلزلت
# outside @siham1800080
# outside #مارس
# outside ل_أجلهم_بل
# outside #ترسيم_البنود_والعقود_والمستخدم
# outside يتفقدك_ويبحث_عنك
# outside #اوصف_حبك_للزمالك_بكلمتين
# outside 160121
# outside الناس_ماقمتي
# outside @HtR8w
# outside @Ahmed_epnmasr
# outside #وظائف_#وظيفتى_#وظائف_شاغرة_#Saudi
# outside الهوى_نحوك
# outside @Ali_Rahhal1
# outside حي_المليك_وحي_هيبة
# outside لما_الوجع_غلب
# outside اللهم_ارزقهم_لطف
# outside #كل_الموضوع
# outside يغلبك_إحساس_العجز
# outside @0TLMZ
# outside #مقدرش_ابعد_عن
# outside ل_الذين_يتركون
# outside أيضا_بجدية_عن
# outside #يوم_السياحة_الأردني
# outside #بناتنا_رائدات_ولسنا_لاعبات
# outside @2zf__
# outside @2sn__
# outside #panamapapers
# outside 8اتبع_الخطوات_1_اضغط
# outside #غرد_ضد_الظلم
# outside #كل_عام_وانت_النبيه
# outside #نطالب_بايقاف_الفريدي
# outside #لو_اني_مو_سعوديه
# outside بجامة
# outside سفوح
# outside كل_محتلم
# outside مسلم
# مسلم
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-f99333e5c64b> in <module>
# ----> 1 word_embeddings = get_word_embeddings('D:\Mazajak100m.vec', tokenizer.word_index, 300)
#
# <ipython-input-14-430a304208d2> in get_word_embeddings(filepath, vocab, embedding_dimension)
#      11     if word in vocab:
#      12       print(word)
# ---> 13       word_vector = np.asarray(line[1:], dtype = "float32")
#      14       if len(word_vector) == embedding_dimension:
#      15         word_embeddings[vocab[word]] = word_vector
#
# ~\anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: '#Hadith'

# %%
# Out:
# <function dict.__getitem__>
